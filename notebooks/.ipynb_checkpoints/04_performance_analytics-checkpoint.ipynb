# %%
for df in [nav, fm, bm, perf]:
    df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
from scipy import stats
from pathlib import Path
import warnings
warnings.filterwarnings("ignore")

PROCESSED = Path("../data/processed")
REPORTS   = Path("../reports")
REPORTS.mkdir(exist_ok=True)

plt.rcParams["figure.figsize"] = (13, 5)
plt.rcParams["figure.dpi"]     = 100
sns.set_theme(style="whitegrid")

#loading data
nav  = pd.read_csv(PROCESSED / "clean_nav.csv", parse_dates=["date"])
fm   = pd.read_csv(PROCESSED / "clean_fund_master.csv")
bm   = pd.read_csv(PROCESSED / "clean_benchmark_indices.csv", parse_dates=["date"])
perf = pd.read_csv(PROCESSED / "clean_performance.csv")

#sort NAV properly
nav = nav.sort_values(["amfi_code", "date"]).reset_index(drop=True)

print("data loaded successfully")
print(f"NAV shape        : {nav.shape}")
print(f"Fund master shape: {fm.shape}")
print(f"Benchmark shape  : {bm.shape}")
# Out:
# data loaded successfully
# NAV shape        : (46000, 3)
# Fund master shape: (40, 15)
# Benchmark shape  : (8050, 3)

# %%
# daily return = (nav_today / nav_yesterday) - 1
nav["daily_return"] = nav.groupby("amfi_code")["nav"].pct_change()

#dropping the first row/fund since it has no return
nav_clean = nav.dropna(subset=["daily_return"]).copy()


nav_clean.to_csv(PROCESSED / "returns_computed.csv", index=False)

print(f"daily returns computed for {nav_clean['amfi_code'].nunique()} funds")
print(nav_clean[["amfi_code","date","nav","daily_return"]].head(10))
# Out:
# daily returns computed for 40 funds
#     amfi_code       date       nav  daily_return
# 1      100016 2022-01-04  515.0971     -0.010306
# 2      100016 2022-01-05  521.7239      0.012865
# 3      100016 2022-01-06  515.7880     -0.011377
# 4      100016 2022-01-07  515.1639     -0.001210
# 5      100016 2022-01-10  510.7136     -0.008639
# 6      100016 2022-01-11  513.5542      0.005562
# 7      100016 2022-01-12  512.3195     -0.002404
# 8      100016 2022-01-13  510.2445     -0.004050
# 9      100016 2022-01-14  514.3636      0.008073
# 10     100016 2022-01-17  514.7627      0.000776

# %%
def compute_cagr(nav_series, years):
   
    trading_days = int(years * 252)
    if len(nav_series) < trading_days:
        return np.nan
    nav_end   = nav_series.iloc[-1]
    nav_start = nav_series.iloc[-trading_days]
    if nav_start <= 0:
        return np.nan
    return (nav_end / nav_start) ** (1 / years) - 1

cagr_records = []
for amfi_code, group in nav.groupby("amfi_code"):
    group = group.sort_values("date")
    nav_series = group["nav"].reset_index(drop=True)
    cagr_records.append({
        "amfi_code"    : amfi_code,
        "cagr_1yr_pct" : round(compute_cagr(nav_series, 1) * 100, 2),
        "cagr_3yr_pct" : round(compute_cagr(nav_series, 3) * 100, 2),
        "cagr_5yr_pct" : round(compute_cagr(nav_series, 5) * 100, 2),
    })

cagr_df = pd.DataFrame(cagr_records)
cagr_df = cagr_df.merge(fm[["amfi_code","scheme_name","sub_category"]], on="amfi_code", how="left")
cagr_df.to_csv(PROCESSED / "cagr_report.csv", index=False)

print("CAGR computed for all funds:")
print(cagr_df[["scheme_name","cagr_1yr_pct","cagr_3yr_pct","cagr_5yr_pct"]].to_string())
# Out:
# CAGR computed for all funds:
#                                               scheme_name  cagr_1yr_pct  cagr_3yr_pct  cagr_5yr_pct
# 0               HDFC Top 100 Fund - Regular Plan - Growth         -3.31         -0.03           NaN
# 1            HDFC Short Term Debt Fund - Regular - Growth          2.50          4.61           NaN
# 2      HDFC Mid-Cap Opportunities Fund - Regular - Growth         47.73         33.63           NaN
# 3           ABSL Frontline Equity Fund - Regular - Growth         45.09         32.53           NaN
# 4                  ABSL Small Cap Fund - Regular - Growth        -24.24         -2.70           NaN
# 5                     ABSL Liquid Fund - Regular - Growth          6.85          6.08           NaN
# 6              UTI Nifty 50 Index Fund - Regular - Growth         18.32         17.52           NaN
# 7                     UTI Mid Cap Fund - Regular - Growth        -13.23         -1.83           NaN
# 8                   UTI Flexi Cap Fund - Regular - Growth         12.73         25.66           NaN
# 9          Nippon India Large Cap Fund - Regular - Growth         21.78         18.09           NaN
# 10          Nippon India Large Cap Fund - Direct - Growth         28.41         18.13           NaN
# 11         Nippon India Small Cap Fund - Regular - Growth         22.37          7.58           NaN
# 12                         Nippon India ETF Nifty 50 BeES         22.00         16.24           NaN
# 13   Nippon India Gilt Securities Fund - Regular - Growth         10.62          4.15           NaN
# 14                  Axis Bluechip Fund - Regular - Growth          3.40          0.56           NaN
# 15                   Axis Bluechip Fund - Direct - Growth         19.79         20.58           NaN
# 16                    Axis Midcap Fund - Regular - Growth         30.92         36.07           NaN
# 17                 Axis Small Cap Fund - Regular - Growth        -45.42        -11.07           NaN
# 18           SBI Magnum Gilt Fund - Regular Plan - Growth          5.72          5.61           NaN
# 19              SBI Bluechip Fund - Regular Plan - Growth         48.88         27.73           NaN
# 20               SBI Bluechip Fund - Direct Plan - Growth          8.25         15.38           NaN
# 21             SBI Small Cap Fund - Regular Plan - Growth         84.53         27.81           NaN
# 22              SBI Small Cap Fund - Direct Plan - Growth         11.91         -0.69           NaN
# 23             ICICI Pru Bluechip Fund - Regular - Growth          4.81         14.80           NaN
# 24              ICICI Pru Bluechip Fund - Direct - Growth         11.50         28.37           NaN
# 25               ICICI Pru Midcap Fund - Regular - Growth         30.35         30.21           NaN
# 26      ICICI Pru Value Discovery Fund - Regular - Growth         32.90         18.25           NaN
# 27               ICICI Pru Liquid Fund - Regular - Growth          7.01          7.05           NaN
# 28                 Kotak Bluechip Fund - Regular - Growth         18.16         16.68           NaN
# 29          Kotak Emerging Equity Fund - Regular - Growth         18.61         10.04           NaN
# 30                 Kotak Flexicap Fund - Regular - Growth         28.48         25.66           NaN
# 31                   Kotak Liquid Fund - Regular - Growth          6.84          6.54           NaN
# 32               HDFC Top 100 Fund - Direct Plan - Growth         29.35         17.71           NaN
# 33      HDFC Mid-Cap Opportunities Fund - Direct - Growth         16.67         12.49           NaN
# 34          Mirae Asset Large Cap Fund - Regular - Growth         14.58         31.28           NaN
# 35  Mirae Asset Emerging Bluechip Fund - Regular - Growth         10.50         13.08           NaN
# 36          Mirae Asset Tax Saver Fund - Regular - Growth         44.47         23.32           NaN
# 37             DSP Top 100 Equity Fund - Regular - Growth         19.13         16.53           NaN
# 38                     DSP Midcap Fund - Regular - Growth         22.31         24.24           NaN
# 39                  DSP Small Cap Fund - Regular - Growth         62.08         25.03           NaN

# %%
RF_ANNUAL = 0.065
RF_DAILY  = RF_ANNUAL / 252

sharpe_records = []
for amfi_code, group in nav_clean.groupby("amfi_code"):
    returns = group["daily_return"]

    ann_return = (1 + returns.mean()) ** 252 - 1
    ann_std    = returns.std() * np.sqrt(252)

    sharpe = (ann_return - RF_ANNUAL) / ann_std if ann_std > 0 else np.nan

    sharpe_records.append({
        "amfi_code"       : amfi_code,
        "ann_return_pct"  : round(ann_return * 100, 2),
        "ann_std_pct"     : round(ann_std * 100, 2),
        "sharpe_ratio"    : round(sharpe, 4),
    })

sharpe_df = pd.DataFrame(sharpe_records)
sharpe_df = sharpe_df.merge(fm[["amfi_code","scheme_name"]], on="amfi_code", how="left")
sharpe_df.to_csv(PROCESSED / "sharpe_values.csv", index=False)

print("Sharpe Ratios computed:")
print(sharpe_df[["scheme_name","ann_return_pct","ann_std_pct","sharpe_ratio"]]
      .sort_values("sharpe_ratio", ascending=False).to_string())
# Out:
# Sharpe Ratios computed:
#                                               scheme_name  ann_return_pct  ann_std_pct  sharpe_ratio
# 34          Mirae Asset Large Cap Fund - Regular - Growth           31.05        14.19        1.7298
# 30                 Kotak Flexicap Fund - Regular - Growth           31.32        15.89        1.5622
# 36          Mirae Asset Tax Saver Fund - Regular - Growth           32.72        17.67        1.4838
# 25               ICICI Pru Midcap Fund - Regular - Growth           33.97        19.29        1.4242
# 19              SBI Bluechip Fund - Regular Plan - Growth           25.98        13.74        1.4174
# 38                     DSP Midcap Fund - Regular - Growth           30.44        17.75        1.3492
# 2      HDFC Mid-Cap Opportunities Fund - Regular - Growth           31.25        18.94        1.3072
# 9          Nippon India Large Cap Fund - Regular - Growth           24.35        14.15        1.2617
# 3           ABSL Frontline Equity Fund - Regular - Growth           23.93        14.57        1.1965
# 24              ICICI Pru Bluechip Fund - Direct - Growth           23.66        14.36        1.1946
# 16                    Axis Midcap Fund - Regular - Growth           29.51        19.41        1.1857
# 39                  DSP Small Cap Fund - Regular - Growth           35.09        24.84        1.1509
# 21             SBI Small Cap Fund - Regular Plan - Growth           35.32        25.14        1.1464
# 20               SBI Bluechip Fund - Direct Plan - Growth           21.87        13.94        1.1028
# 35  Mirae Asset Emerging Bluechip Fund - Regular - Growth           23.10        15.43        1.0759
# 27               ICICI Pru Liquid Fund - Regular - Growth            6.98         0.49        0.9648
# 6              UTI Nifty 50 Index Fund - Regular - Growth           18.51        12.84        0.9356
# 23             ICICI Pru Bluechip Fund - Regular - Growth           19.21        13.88        0.9156
# 32               HDFC Top 100 Fund - Direct Plan - Growth           19.57        14.67        0.8910
# 12                         Nippon India ETF Nifty 50 BeES           16.33        12.98        0.7573
# 26      ICICI Pru Value Discovery Fund - Regular - Growth           17.79        15.23        0.7416
# 10          Nippon India Large Cap Fund - Direct - Growth           16.80        14.00        0.7356
# 8                   UTI Flexi Cap Fund - Regular - Growth           17.65        15.76        0.7078
# 28                 Kotak Bluechip Fund - Regular - Growth           14.06        13.46        0.5612
# 37             DSP Top 100 Equity Fund - Regular - Growth           14.06        14.35        0.5268
# 11         Nippon India Small Cap Fund - Regular - Growth           19.50        25.24        0.5149
# 33      HDFC Mid-Cap Opportunities Fund - Direct - Growth           12.77        18.35        0.3414
# 31                   Kotak Liquid Fund - Regular - Growth            6.67         0.51        0.3242
# 4                  ABSL Small Cap Fund - Regular - Growth           11.29        25.80        0.1855
# 15                   Axis Bluechip Fund - Direct - Growth            8.67        13.98        0.1549
# 29          Kotak Emerging Equity Fund - Regular - Growth            8.18        17.89        0.0936
# 14                  Axis Bluechip Fund - Regular - Growth            7.17        13.95        0.0483
# 22              SBI Small Cap Fund - Direct Plan - Growth            5.20        24.95       -0.0520
# 17                 Axis Small Cap Fund - Regular - Growth            4.70        25.07       -0.0717
# 18           SBI Magnum Gilt Fund - Regular Plan - Growth            5.76         3.97       -0.1865
# 0               HDFC Top 100 Fund - Regular Plan - Growth            3.63        14.55       -0.1971
# 7                     UTI Mid Cap Fund - Regular - Growth            2.81        18.13       -0.2037
# 13   Nippon India Gilt Securities Fund - Regular - Growth            5.21         3.99       -0.3239
# 5                     ABSL Liquid Fund - Regular - Growth            6.28         0.51       -0.4438
# 1            HDFC Short Term Debt Fund - Regular - Growth            4.38         3.91       -0.5433

# %%
# Sortino records = (Annualised Return - Rf) / Downside Std Dev

sortino_records = []
for amfi_code, group in nav_clean.groupby("amfi_code"):
    returns = group["daily_return"]

    ann_return    = (1 + returns.mean()) ** 252 - 1
    downside_only = returns[returns < 0]
    downside_std  = downside_only.std() * np.sqrt(252)

    sortino = (ann_return - RF_ANNUAL) / downside_std if downside_std > 0 else np.nan

    sortino_records.append({
        "amfi_code"     : amfi_code,
        "sortino_ratio" : round(sortino, 4),
        "downside_std"  : round(downside_std * 100, 2),
    })

sortino_df = pd.DataFrame(sortino_records)
sortino_df = sortino_df.merge(fm[["amfi_code","scheme_name"]], on="amfi_code", how="left")
sortino_df.to_csv(PROCESSED / "sortino_values.csv", index=False)

print("Sortino Ratios computed:")
print(sortino_df[["scheme_name","sortino_ratio","downside_std"]]
      .sort_values("sortino_ratio", ascending=False).to_string())
# Out:
# Sortino Ratios computed:
#                                               scheme_name  sortino_ratio  downside_std
# 34          Mirae Asset Large Cap Fund - Regular - Growth         2.8493          8.62
# 30                 Kotak Flexicap Fund - Regular - Growth         2.8265          8.78
# 36          Mirae Asset Tax Saver Fund - Regular - Growth         2.5795         10.17
# 19              SBI Bluechip Fund - Regular Plan - Growth         2.5107          7.76
# 25               ICICI Pru Midcap Fund - Regular - Growth         2.4492         11.22
# 38                     DSP Midcap Fund - Regular - Growth         2.2347         10.71
# 2      HDFC Mid-Cap Opportunities Fund - Regular - Growth         2.1862         11.32
# 9          Nippon India Large Cap Fund - Regular - Growth         2.1582          8.27
# 24              ICICI Pru Bluechip Fund - Direct - Growth         2.1009          8.17
# 3           ABSL Frontline Equity Fund - Regular - Growth         2.0962          8.32
# 27               ICICI Pru Liquid Fund - Regular - Growth         2.0478          0.23
# 21             SBI Small Cap Fund - Regular Plan - Growth         2.0316         14.19
# 16                    Axis Midcap Fund - Regular - Growth         2.0238         11.37
# 39                  DSP Small Cap Fund - Regular - Growth         1.9627         14.57
# 35  Mirae Asset Emerging Bluechip Fund - Regular - Growth         1.8965          8.75
# 20               SBI Bluechip Fund - Direct Plan - Growth         1.8623          8.25
# 6              UTI Nifty 50 Index Fund - Regular - Growth         1.6440          7.31
# 23             ICICI Pru Bluechip Fund - Regular - Growth         1.5351          8.28
# 32               HDFC Top 100 Fund - Direct Plan - Growth         1.5283          8.55
# 10          Nippon India Large Cap Fund - Direct - Growth         1.3162          7.82
# 12                         Nippon India ETF Nifty 50 BeES         1.2961          7.59
# 26      ICICI Pru Value Discovery Fund - Regular - Growth         1.2525          9.02
# 8                   UTI Flexi Cap Fund - Regular - Growth         1.2439          8.97
# 28                 Kotak Bluechip Fund - Regular - Growth         0.9793          7.72
# 37             DSP Top 100 Equity Fund - Regular - Growth         0.8653          8.74
# 11         Nippon India Small Cap Fund - Regular - Growth         0.8567         15.17
# 31                   Kotak Liquid Fund - Regular - Growth         0.6858          0.24
# 33      HDFC Mid-Cap Opportunities Fund - Direct - Growth         0.5779         10.84
# 4                  ABSL Small Cap Fund - Regular - Growth         0.3156         15.17
# 15                   Axis Bluechip Fund - Direct - Growth         0.2642          8.20
# 29          Kotak Emerging Equity Fund - Regular - Growth         0.1537         10.91
# 14                  Axis Bluechip Fund - Regular - Growth         0.0825          8.17
# 22              SBI Small Cap Fund - Direct Plan - Growth        -0.0858         15.12
# 17                 Axis Small Cap Fund - Regular - Growth        -0.1210         14.86
# 18           SBI Magnum Gilt Fund - Regular Plan - Growth        -0.3100          2.39
# 0               HDFC Top 100 Fund - Regular Plan - Growth        -0.3434          8.35
# 7                     UTI Mid Cap Fund - Regular - Growth        -0.3436         10.75
# 13   Nippon India Gilt Securities Fund - Regular - Growth        -0.5571          2.32
# 1            HDFC Short Term Debt Fund - Regular - Growth        -0.9024          2.35
# 5                     ABSL Liquid Fund - Regular - Growth        -0.9147          0.25

# %%
nav_clean = nav_clean.sort_values("date")
nifty100  = nifty100.sort_values("date")

alpha_beta_records = []

for amfi_code, group in nav_clean.groupby("amfi_code"):

    fund = group[["date","daily_return"]].sort_values("date")

    merged = pd.merge_asof(
        fund,
        nifty100,
        on="date",
        direction="backward"
    )

    merged = merged.dropna()

    if len(merged) < 30:
        continue

    fund_r = merged["daily_return"].values
    bm_r   = merged["bm_return"].values

    slope, intercept, r_value, _, _ = stats.linregress(bm_r, fund_r)

    alpha_beta_records.append({
        "amfi_code": amfi_code,
        "beta": round(slope, 4),
        "alpha_ann": round(intercept * 252 * 100, 2),
        "r_squared": round(r_value ** 2, 4)
    })

ab_df = pd.DataFrame(alpha_beta_records)

print("Rows generated:", len(ab_df))
# Out:
# Rows generated: 0

# %%
# Max Drawdown = min(NAV / running_max - 1)
# It tells you the worst peak to trough loss a fund experienced

drawdown_records = []
for amfi_code, group in nav.groupby("amfi_code"):
    group     = group.sort_values("date")
    nav_vals  = group["nav"].values
    dates     = group["date"].values

    running_max = np.maximum.accumulate(nav_vals)
    drawdowns   = (nav_vals / running_max) - 1
    max_dd      = drawdowns.min()
    max_dd_date = dates[np.argmin(drawdowns)]

    drawdown_records.append({
        "amfi_code"      : amfi_code,
        "max_drawdown_pct": round(max_dd * 100, 2),
        "max_dd_date"    : str(max_dd_date)[:10],
    })

dd_df = pd.DataFrame(drawdown_records)
dd_df = dd_df.merge(fm[["amfi_code","scheme_name","sub_category"]], on="amfi_code", how="left")
dd_df.to_csv(PROCESSED / "max_drawdown.csv", index=False)

print("Maximum Drawdown computed:")
print(dd_df[["scheme_name","max_drawdown_pct","max_dd_date"]]
      .sort_values("max_drawdown_pct").to_string())
# Out:
# Maximum Drawdown computed:
#                                               scheme_name  max_drawdown_pct max_dd_date
# 22              SBI Small Cap Fund - Direct Plan - Growth            -52.57  2025-10-28
# 17                 Axis Small Cap Fund - Regular - Growth            -51.68  2026-05-11
# 4                  ABSL Small Cap Fund - Regular - Growth            -35.45  2026-05-11
# 39                  DSP Small Cap Fund - Regular - Growth            -31.17  2025-01-03
# 21             SBI Small Cap Fund - Regular Plan - Growth            -28.71  2025-05-14
# 7                     UTI Mid Cap Fund - Regular - Growth            -28.00  2026-04-27
# 0               HDFC Top 100 Fund - Regular Plan - Growth            -24.73  2022-09-15
# 29          Kotak Emerging Equity Fund - Regular - Growth            -24.00  2024-10-17
# 11         Nippon India Small Cap Fund - Regular - Growth            -23.34  2026-02-20
# 15                   Axis Bluechip Fund - Direct - Growth            -21.75  2023-05-22
# 8                   UTI Flexi Cap Fund - Regular - Growth            -21.54  2022-07-04
# 33      HDFC Mid-Cap Opportunities Fund - Direct - Growth            -21.12  2025-09-12
# 16                    Axis Midcap Fund - Regular - Growth            -20.96  2022-08-11
# 26      ICICI Pru Value Discovery Fund - Regular - Growth            -19.83  2023-08-14
# 10          Nippon India Large Cap Fund - Direct - Growth            -18.63  2024-02-29
# 25               ICICI Pru Midcap Fund - Regular - Growth            -18.19  2025-01-23
# 28                 Kotak Bluechip Fund - Regular - Growth            -17.57  2025-02-14
# 9          Nippon India Large Cap Fund - Regular - Growth            -17.41  2024-07-19
# 38                     DSP Midcap Fund - Regular - Growth            -17.25  2022-10-24
# 36          Mirae Asset Tax Saver Fund - Regular - Growth            -16.40  2023-10-20
# 2      HDFC Mid-Cap Opportunities Fund - Regular - Growth            -16.22  2022-05-12
# 35  Mirae Asset Emerging Bluechip Fund - Regular - Growth            -15.27  2024-01-24
# 32               HDFC Top 100 Fund - Direct Plan - Growth            -15.20  2025-01-01
# 19              SBI Bluechip Fund - Regular Plan - Growth            -15.01  2024-02-05
# 37             DSP Top 100 Equity Fund - Regular - Growth            -14.84  2022-02-04
# 14                  Axis Bluechip Fund - Regular - Growth            -14.40  2025-02-07
# 23             ICICI Pru Bluechip Fund - Regular - Growth            -13.90  2023-11-09
# 30                 Kotak Flexicap Fund - Regular - Growth            -12.97  2022-04-13
# 24              ICICI Pru Bluechip Fund - Direct - Growth            -12.59  2023-05-30
# 20               SBI Bluechip Fund - Direct Plan - Growth            -11.80  2024-09-02
# 12                         Nippon India ETF Nifty 50 BeES            -11.65  2022-06-09
# 3           ABSL Frontline Equity Fund - Regular - Growth            -11.29  2023-07-05
# 34          Mirae Asset Large Cap Fund - Regular - Growth            -11.27  2023-10-20
# 6              UTI Nifty 50 Index Fund - Regular - Growth            -10.86  2022-03-29
# 13   Nippon India Gilt Securities Fund - Regular - Growth             -8.32  2024-02-09
# 18           SBI Magnum Gilt Fund - Regular Plan - Growth             -4.33  2025-04-01
# 1            HDFC Short Term Debt Fund - Regular - Growth             -4.31  2023-07-28
# 5                     ABSL Liquid Fund - Regular - Growth             -0.16  2023-09-12
# 31                   Kotak Liquid Fund - Regular - Growth             -0.12  2024-04-30
# 27               ICICI Pru Liquid Fund - Regular - Growth             -0.10  2025-10-20

# %%
# Composite Score Formula:
# 30% × 3yr CAGR rank
# 25% × Sharpe rank
# 20% × Alpha rank
# 15% × Expense ratio rank (inverse — lower is better)
# 10% × Max drawdown rank (inverse — less negative is better)

scorecard = cagr_df[["amfi_code","scheme_name","sub_category","cagr_3yr_pct"]].copy()
scorecard = scorecard.merge(sharpe_df[["amfi_code","sharpe_ratio"]], on="amfi_code", how="left")
scorecard = scorecard.merge(dd_df[["amfi_code","max_drawdown_pct"]], on="amfi_code", how="left")
scorecard = scorecard.merge(fm[["amfi_code","expense_ratio_pct"]], on="amfi_code", how="left")

scorecard = scorecard.dropna().copy()
n = len(scorecard)

# rank each metric (higher rank = better)
scorecard["rank_cagr3"]    = scorecard["cagr_3yr_pct"].rank()
scorecard["rank_sharpe"]   = scorecard["sharpe_ratio"].rank()
scorecard["rank_expense"]  = (n + 1) - scorecard["expense_ratio_pct"].rank()  # inverse
scorecard["rank_drawdown"] = (n + 1) - scorecard["max_drawdown_pct"].rank()   # inverse (less negative = better)

# normalise ranks to 0-100
for col in ["rank_cagr3","rank_sharpe","rank_expense","rank_drawdown"]:
    scorecard[col] = (scorecard[col] / n) * 100

# weighted composite score
scorecard["composite_score"] = (
    0.35 * scorecard["rank_cagr3"]   +
    0.3 * scorecard["rank_sharpe"]  +
    0.2 * scorecard["rank_expense"] +
    0.15 * scorecard["rank_drawdown"]
).round(2)

scorecard = scorecard.sort_values("composite_score", ascending=False).reset_index(drop=True)
scorecard["fund_rank"] = scorecard.index + 1

scorecard.to_csv(PROCESSED / "fund_scorecard.csv", index=False)

print("Fund Scorecard — Top 10:")
print(scorecard[["fund_rank","scheme_name","sub_category",
                  "cagr_3yr_pct","sharpe_ratio","composite_score"]].head(10).to_string())
# Out:
# Fund Scorecard — Top 10:
#    fund_rank                                         scheme_name sub_category  cagr_3yr_pct  sharpe_ratio  composite_score
# 0          1            ICICI Pru Midcap Fund - Regular - Growth      Mid Cap         30.21        1.4242            81.62
# 1          2                 Axis Midcap Fund - Regular - Growth      Mid Cap         36.07        1.1857            80.00
# 2          3  HDFC Mid-Cap Opportunities Fund - Regular - Growth      Mid Cap         33.63        1.3072            79.12
# 3          4       Mirae Asset Large Cap Fund - Regular - Growth    Large Cap         31.28        1.7298            74.38
# 4          5          SBI Small Cap Fund - Regular Plan - Growth    Small Cap         27.81        1.1464            74.25
# 5          6           ICICI Pru Bluechip Fund - Direct - Growth    Large Cap         28.37        1.1946            72.88
# 6          7              Kotak Flexicap Fund - Regular - Growth    Flexi Cap         25.66        1.5622            71.19
# 7          8               DSP Small Cap Fund - Regular - Growth    Small Cap         25.03        1.1509            69.12
# 8          9           SBI Bluechip Fund - Regular Plan - Growth    Large Cap         27.73        1.4174            67.50
# 9         10       Nippon India Large Cap Fund - Direct - Growth    Large Cap         18.13        0.7356            63.62

# %%
# compare top 5 scoring funds vs Nifty 50 and Nifty 100 over 3 years

top5_codes = scorecard.head(5)["amfi_code"].tolist()
top5_names = scorecard.head(5).set_index("amfi_code")["scheme_name"].str[:25].to_dict()

# filter last 3 years
cutoff = nav["date"].max() - pd.DateOffset(years=3)
nav_top5 = nav[(nav["amfi_code"].isin(top5_codes)) & (nav["date"] >= cutoff)].copy()

# normalise to 100 at start for fair comparison
def normalise(series):
    return (series / series.iloc[0]) * 100

fig, ax = plt.subplots(figsize=(14, 6))

for code in top5_codes:
    data = nav_top5[nav_top5["amfi_code"] == code].sort_values("date")
    normalised = normalise(data["nav"].reset_index(drop=True))
    ax.plot(data["date"].values, normalised.values,
            label=top5_names.get(code, code), linewidth=1.5)

# add benchmarks
for idx_name, color, ls in [("Nifty 50","black","--"), ("Nifty 100","gray","-.")]:
    bm_data = bm[(bm["index_name"] == idx_name) & (bm["date"] >= cutoff)].sort_values("date")
    bm_norm = normalise(bm_data["close"].reset_index(drop=True))
    ax.plot(bm_data["date"].values, bm_norm.values,
            label=idx_name, color=color, linestyle=ls, linewidth=2)

ax.set_title("Top 5 Funds vs Nifty 50 & Nifty 100 — 3 Year Performance (Base = 100)",
             fontsize=13, fontweight="bold")
ax.set_xlabel("Date")
ax.set_ylabel("Indexed Return (Base 100)")
ax.legend(bbox_to_anchor=(1.01, 1), loc="upper left", fontsize=8)
ax.axhline(y=100, color="red", linestyle=":", linewidth=0.8, alpha=0.5)
plt.tight_layout()
plt.savefig(REPORTS / "benchmark_chart.png", dpi=150)
plt.show()
print("Benchmark chart saved")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 25
#      23 for idx_name, color, ls in [("Nifty 50","black","--"), ("Nifty 100","gray","-.")]:
#      24     bm_data = bm[(bm["index_name"] == idx_name) & (bm["date"] >= cutoff)].sort_values("date")
# ---> 25     bm_norm = normalise(bm_data["close"].reset_index(drop=True))
#      26     ax.plot(bm_data["date"].values, bm_norm.values,
#      27             label=idx_name, color=color, linestyle=ls, linewidth=2)
#      29 ax.set_title("Top 5 Funds vs Nifty 50 & Nifty 100 — 3 Year Performance (Base = 100)",
#      30              fontsize=13, fontweight="bold")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'close'
